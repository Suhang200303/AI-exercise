# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# 超参数设置
batch_size = 128
learning_rate = 0.01


# CIFAR-100数据集
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# CCNet模块的定义
class CrissCrossAttention(nn.Module):
    def __init__(self, in_dim):
        super(CrissCrossAttention, self).__init__()
        self.query_conv = nn.Conv2d(in_dim, in_dim // 8, kernel_size=1)
        self.key_conv = nn.Conv2d(in_dim, in_dim // 8, kernel_size=1)
        self.value_conv = nn.Conv2d(in_dim, in_dim, kernel_size=1)
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):
        batch_size, C, width, height = x.size()
        proj_query = self.query_conv(x).view(batch_size, -1, width * height)  # [B, C/8, N]
        proj_key = self.key_conv(x).view(batch_size, -1, width * height)  # [B, C/8, N]
        energy = torch.bmm(proj_query.permute(0, 2, 1), proj_key)  # [B, N, N]
        attention = torch.softmax(energy, dim=-1)
        proj_value = self.value_conv(x).view(batch_size, -1, width * height)  # [B, C, N]

        out = torch.bmm(proj_value, attention.permute(0, 2, 1))  # [B, C, N]
        out = out.view(batch_size, C, width, height)
        
        out = self.gamma * out + x
        return out

# 定义一个简单的CNN模型，并嵌入CCNet模块
class CCNetCNN(nn.Module):
    def __init__(self):
        super(CCNetCNN, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            CrissCrossAttention(64),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            CrissCrossAttention(128),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            CrissCrossAttention(256),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.fc = nn.Linear(256 * 4 * 4, 100)  # CIFAR-100有100个类别

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# 模型实例化，损失函数和优化器定义
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CCNetCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# 学习率调整策略
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train_and_evaluate(model, trainloader, testloader, num_epochs=10):


    train_losses = []
    train_accuracies = []
    test_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(trainloader)
        epoch_acc = 100 * correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)
        
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
        test_accuracies.append(test_acc)

        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.2f}%, Test Accuracy: {test_acc:.2f}%')
        scheduler.step()
     # 绘制损失和准确度曲线
    epochs = range(1, num_epochs + 1)

    plt.figure(figsize=(12, 5))

    # 绘制训练损失曲线
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'b', label='Training loss')
    plt.title('Training loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # 绘制训练和测试准确度曲线
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'b', label='Training accuracy')
    plt.plot(epochs, test_accuracies, 'r', label='Test accuracy')
    plt.title('Training and Test accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')   
print(device)
# Out:
# cuda

# %%
train_and_evaluate(model, trainloader, testloader, num_epochs=100)
# Out:
# Epoch [1/100], Loss: 4.7658, Train Accuracy: 10.61%, Test Accuracy: 17.26%
# Epoch [2/100], Loss: 3.1797, Train Accuracy: 23.18%, Test Accuracy: 26.95%
# Epoch [3/100], Loss: 2.7281, Train Accuracy: 31.47%, Test Accuracy: 33.92%
# Epoch [4/100], Loss: 2.4324, Train Accuracy: 38.07%, Test Accuracy: 38.39%
# Epoch [5/100], Loss: 2.2276, Train Accuracy: 42.47%, Test Accuracy: 41.13%
# Epoch [6/100], Loss: 2.0756, Train Accuracy: 45.59%, Test Accuracy: 41.87%
# Epoch [7/100], Loss: 1.9561, Train Accuracy: 48.27%, Test Accuracy: 43.62%
# Epoch [8/100], Loss: 1.8664, Train Accuracy: 50.32%, Test Accuracy: 46.35%
# Epoch [9/100], Loss: 1.7860, Train Accuracy: 52.03%, Test Accuracy: 42.58%
# Epoch [10/100], Loss: 1.7178, Train Accuracy: 53.44%, Test Accuracy: 47.04%
# Epoch [11/100], Loss: 1.6521, Train Accuracy: 54.98%, Test Accuracy: 47.77%
# Epoch [12/100], Loss: 1.6103, Train Accuracy: 55.94%, Test Accuracy: 47.44%
# Epoch [13/100], Loss: 1.5574, Train Accuracy: 57.43%, Test Accuracy: 49.33%
# Epoch [14/100], Loss: 1.5191, Train Accuracy: 58.12%, Test Accuracy: 49.59%
# Epoch [15/100], Loss: 1.4873, Train Accuracy: 58.83%, Test Accuracy: 48.53%
# Epoch [16/100], Loss: 1.4501, Train Accuracy: 59.63%, Test Accuracy: 49.40%
# Epoch [17/100], Loss: 1.4307, Train Accuracy: 60.02%, Test Accuracy: 50.71%
# Epoch [18/100], Loss: 1.3915, Train Accuracy: 61.05%, Test Accuracy: 51.37%
# Epoch [19/100], Loss: 1.3698, Train Accuracy: 61.70%, Test Accuracy: 49.94%
# Epoch [20/100], Loss: 1.3409, Train Accuracy: 62.39%, Test Accuracy: 49.89%
# Epoch [21/100], Loss: 1.3155, Train Accuracy: 62.87%, Test Accuracy: 51.13%
# Epoch [22/100], Loss: 1.2981, Train Accuracy: 63.35%, Test Accuracy: 50.82%
# Epoch [23/100], Loss: 1.2907, Train Accuracy: 63.67%, Test Accuracy: 51.10%
# Epoch [24/100], Loss: 1.2586, Train Accuracy: 64.31%, Test Accuracy: 52.12%
# Epoch [25/100], Loss: 1.2558, Train Accuracy: 64.11%, Test Accuracy: 46.34%
# Epoch [26/100], Loss: 1.2306, Train Accuracy: 64.84%, Test Accuracy: 51.19%
# Epoch [27/100], Loss: 1.2155, Train Accuracy: 65.40%, Test Accuracy: 52.25%
# Epoch [28/100], Loss: 1.1928, Train Accuracy: 65.64%, Test Accuracy: 51.73%
# Epoch [29/100], Loss: 1.1723, Train Accuracy: 66.37%, Test Accuracy: 49.76%
# Epoch [30/100], Loss: 1.1535, Train Accuracy: 66.82%, Test Accuracy: 51.94%
# Epoch [31/100], Loss: 0.8938, Train Accuracy: 73.58%, Test Accuracy: 56.21%
# Epoch [32/100], Loss: 0.8267, Train Accuracy: 75.24%, Test Accuracy: 57.03%
# Epoch [33/100], Loss: 0.7991, Train Accuracy: 76.52%, Test Accuracy: 56.92%
# Epoch [34/100], Loss: 0.7697, Train Accuracy: 77.14%, Test Accuracy: 57.23%
# Epoch [35/100], Loss: 0.7566, Train Accuracy: 77.70%, Test Accuracy: 57.47%
# Epoch [36/100], Loss: 0.7466, Train Accuracy: 77.81%, Test Accuracy: 57.11%
# Epoch [37/100], Loss: 0.7294, Train Accuracy: 78.19%, Test Accuracy: 57.90%
# Epoch [38/100], Loss: 0.7185, Train Accuracy: 78.44%, Test Accuracy: 57.25%
# Epoch [39/100], Loss: 0.7099, Train Accuracy: 78.88%, Test Accuracy: 57.28%
# Epoch [40/100], Loss: 0.6961, Train Accuracy: 79.07%, Test Accuracy: 57.44%
# Epoch [41/100], Loss: 0.6797, Train Accuracy: 79.48%, Test Accuracy: 57.81%
# Epoch [42/100], Loss: 0.6763, Train Accuracy: 79.57%, Test Accuracy: 57.75%
# Epoch [43/100], Loss: 0.6699, Train Accuracy: 79.78%, Test Accuracy: 57.16%
# Epoch [44/100], Loss: 0.6651, Train Accuracy: 80.04%, Test Accuracy: 57.73%
# Epoch [45/100], Loss: 0.6556, Train Accuracy: 80.22%, Test Accuracy: 57.65%
# Epoch [46/100], Loss: 0.6477, Train Accuracy: 80.52%, Test Accuracy: 57.77%
# Epoch [47/100], Loss: 0.6342, Train Accuracy: 80.66%, Test Accuracy: 57.13%
# Epoch [48/100], Loss: 0.6207, Train Accuracy: 81.01%, Test Accuracy: 57.54%
# Epoch [49/100], Loss: 0.6230, Train Accuracy: 81.00%, Test Accuracy: 57.26%
# Epoch [50/100], Loss: 0.6136, Train Accuracy: 81.20%, Test Accuracy: 57.59%
# Epoch [51/100], Loss: 0.6082, Train Accuracy: 81.44%, Test Accuracy: 58.12%
# Epoch [52/100], Loss: 0.6053, Train Accuracy: 81.59%, Test Accuracy: 57.78%
# Epoch [53/100], Loss: 0.6006, Train Accuracy: 81.63%, Test Accuracy: 58.35%
# Epoch [54/100], Loss: 0.5962, Train Accuracy: 81.86%, Test Accuracy: 57.33%
# Epoch [55/100], Loss: 0.5876, Train Accuracy: 81.87%, Test Accuracy: 57.76%
# Epoch [56/100], Loss: 0.5890, Train Accuracy: 81.91%, Test Accuracy: 57.89%
# Epoch [57/100], Loss: 0.5782, Train Accuracy: 82.36%, Test Accuracy: 57.80%
# Epoch [58/100], Loss: 0.5611, Train Accuracy: 82.62%, Test Accuracy: 57.82%
# Epoch [59/100], Loss: 0.5635, Train Accuracy: 82.79%, Test Accuracy: 58.02%
# Epoch [60/100], Loss: 0.5585, Train Accuracy: 82.81%, Test Accuracy: 57.76%
# Epoch [61/100], Loss: 0.5357, Train Accuracy: 83.56%, Test Accuracy: 57.97%
# Epoch [62/100], Loss: 0.5404, Train Accuracy: 83.45%, Test Accuracy: 58.05%
# Epoch [63/100], Loss: 0.5277, Train Accuracy: 83.90%, Test Accuracy: 58.62%
# Epoch [64/100], Loss: 0.5279, Train Accuracy: 83.76%, Test Accuracy: 58.21%
# Epoch [65/100], Loss: 0.5209, Train Accuracy: 83.89%, Test Accuracy: 58.41%
# Epoch [66/100], Loss: 0.5210, Train Accuracy: 84.07%, Test Accuracy: 58.34%
# Epoch [67/100], Loss: 0.5152, Train Accuracy: 84.07%, Test Accuracy: 58.52%
# Epoch [68/100], Loss: 0.5188, Train Accuracy: 84.19%, Test Accuracy: 58.15%
# Epoch [69/100], Loss: 0.5218, Train Accuracy: 84.16%, Test Accuracy: 58.56%
# Epoch [70/100], Loss: 0.5242, Train Accuracy: 83.92%, Test Accuracy: 58.63%
# Epoch [71/100], Loss: 0.5159, Train Accuracy: 84.01%, Test Accuracy: 57.86%
# Epoch [72/100], Loss: 0.5173, Train Accuracy: 83.97%, Test Accuracy: 58.41%
# Epoch [73/100], Loss: 0.5219, Train Accuracy: 83.91%, Test Accuracy: 58.28%
# Epoch [74/100], Loss: 0.5145, Train Accuracy: 84.09%, Test Accuracy: 58.27%
# Epoch [75/100], Loss: 0.5114, Train Accuracy: 84.22%, Test Accuracy: 58.16%
# Epoch [76/100], Loss: 0.5140, Train Accuracy: 84.19%, Test Accuracy: 58.01%
# Epoch [77/100], Loss: 0.5118, Train Accuracy: 84.36%, Test Accuracy: 58.24%
# Epoch [78/100], Loss: 0.5153, Train Accuracy: 84.08%, Test Accuracy: 57.98%
# Epoch [79/100], Loss: 0.5201, Train Accuracy: 84.08%, Test Accuracy: 58.07%
# Epoch [80/100], Loss: 0.5050, Train Accuracy: 84.38%, Test Accuracy: 58.90%
# Epoch [81/100], Loss: 0.5125, Train Accuracy: 84.19%, Test Accuracy: 58.26%
# Epoch [82/100], Loss: 0.5084, Train Accuracy: 84.43%, Test Accuracy: 58.69%
# Epoch [83/100], Loss: 0.5110, Train Accuracy: 84.23%, Test Accuracy: 58.56%
# Epoch [84/100], Loss: 0.5036, Train Accuracy: 84.64%, Test Accuracy: 58.59%
# Epoch [85/100], Loss: 0.5108, Train Accuracy: 84.27%, Test Accuracy: 58.81%
# Epoch [86/100], Loss: 0.5028, Train Accuracy: 84.44%, Test Accuracy: 58.46%
# Epoch [87/100], Loss: 0.5091, Train Accuracy: 84.44%, Test Accuracy: 58.50%
# Epoch [88/100], Loss: 0.5019, Train Accuracy: 84.60%, Test Accuracy: 57.69%
# Epoch [89/100], Loss: 0.5027, Train Accuracy: 84.40%, Test Accuracy: 58.65%
# Epoch [90/100], Loss: 0.5028, Train Accuracy: 84.45%, Test Accuracy: 58.34%
# Epoch [91/100], Loss: 0.5055, Train Accuracy: 84.42%, Test Accuracy: 58.33%
# Epoch [92/100], Loss: 0.4974, Train Accuracy: 84.77%, Test Accuracy: 58.45%
# Epoch [93/100], Loss: 0.4977, Train Accuracy: 84.69%, Test Accuracy: 59.16%
# Epoch [94/100], Loss: 0.4973, Train Accuracy: 84.67%, Test Accuracy: 58.34%
# Epoch [95/100], Loss: 0.4992, Train Accuracy: 84.72%, Test Accuracy: 58.12%
# Epoch [96/100], Loss: 0.5039, Train Accuracy: 84.44%, Test Accuracy: 58.05%
# Epoch [97/100], Loss: 0.4939, Train Accuracy: 84.61%, Test Accuracy: 58.79%
# Epoch [98/100], Loss: 0.5006, Train Accuracy: 84.60%, Test Accuracy: 58.26%
# Epoch [99/100], Loss: 0.5027, Train Accuracy: 84.58%, Test Accuracy: 58.04%
# Epoch [100/100], Loss: 0.4978, Train Accuracy: 84.79%, Test Accuracy: 58.16%
